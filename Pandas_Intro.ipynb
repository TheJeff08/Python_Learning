# %%
import pandas as pd
import sys
print(sys.version)
print('pandas version', pd.__version__)
# Out:
# 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:20:11) [MSC v.1938 64 bit (AMD64)]
# pandas version 2.2.3

# %% [markdown]
# #### I/O (Reading and Writing)

# %%
pd.read_excel("E:/Learning_Files/titanic3.xls")  # Note the / usage and double quotes
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df = pd.read_excel("E:/Learning_Files/titanic3.xls")  # Just naming the DataFrame so that it's easier to reference

# %% [markdown]
# #### DataFrame Basics

# %%
df.head()  # Lets you see the first 5 rows by default - can expand this by using pd.set_option('display.max_columns', num_of_columns)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.tail() # Will show the last 5 rows of the DataFrame
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
df.sample() # Shows a random selection of rows, can also put in a number in the () to pull a specific, or use frac= in the () to determine a fraction of the dataset to be displayed
# Out:
#      pclass  survived                     name     sex  age  sibsp  parch  \
# 108       1         1  Fleming, Miss. Margaret  female  NaN      0      0
#
#     ticket      fare cabin embarked boat  body home.dest
# 108  17421  110.8833   NaN        C    4   NaN       NaN

# %%
df.columns # will list out the columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.index # Will likewise give the index valuse of the DataFrame
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
df.info() # Will show info about the DataFrame can set verbose=FALSE in the () to slim it down
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.describe()  # Gives a top down of the stats, also you can insert a specific column to get other info for ex. df[['column_name']].describe() and it could pull other info based on the column itself
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.shape  # Gives the shape of the DataFrame, can also for example get just the length by doing df.shape, len(df)
# Out:
# (1309, 14)

# %%
df.isnull() # Not the most helpful, but it does show is that in every "true" there is no value there
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# ...

# %%
# We can determine how many null values there are by using .sum()
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
# We now see how many null values exist in each column
# But what if I just want a number of the null values on the data set?

# %%
df.isnull().sum().sum()
# Out:
# np.int64(3855)

# %%
# Decide how to deal with these null values
# First we can fill the null values
df.fillna(value = 0)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# For ease of use we can redefine the DataFrame with the null values
df2 = df.fillna(value = 0)

# %%
df2.isnull().sum().sum() # We can check now if there are any null values in our new dataset, just like we did before
# Out:
# np.int64(0)

# %%
# Filling null values with previous value in the list
df3 = df.ffill()
df3
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# And again, check to see if there are any nulls
df3.isnull().sum().sum()

# In this case, there is no previous value for the upper value, so those first couple have no value to fill, until there is a cell with a value previous
# Out:
# np.int64(3)

# %%
# Filling the values with the next value

df4 = df.bfill()
df4
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# You can likewise fill the null values with the previous or next column (previous being left, next being right) by doing like dfx = df.ffill(axis = 1) same with bfill

# %%
# We can also fill different columns with different values by defining a function

df5 = df.fillna({'age': 'Unknown',
                 'cabin': 'Who_knows'})
df5
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare      cabin embarked  \
# ...

# %% [markdown]
# #### Subsetting a DataFrame

# %%
df[['pclass', 'survived', 'name']]  # Will display just the listed columns - running df.columns will give you the names, or you could slice it doing df[df.columns[5:]] to get the first 5
# Less commonly, you can use a dtype to filter columns, for example df.select_dtypes('int') to return only columns that are typed as integers
# Out:
#       pclass  survived                                             name
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
# [1309 rows x 3 columns]

# %%
# If you include a single column, you'll be presented with a series, i.e.
df['p]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 1309, dtype: int64

# %%
# When wanting to do just a single column, use double brackets to return the full thing as a DataFrame
df[['pclass']]
# Out:
#       pclass
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 1304       3
# 1305       3
# 1306       3
# 1307       3
# 1308       3
#
# [1309 rows x 1 columns]

# %% [markdown]
# #### Filtering Rows
# ##### df.loc[] and df.iloc[]

# %%
# df.iloc[] will use the index location, and df.loc[] will use the names

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# Say we wanted the age of the person in row 2, Allison, Miss. Helen Loraine
df.iloc[2, 4] # Keeping in mind counting starts at 0, and in this example the header columns and the 0,1,2,3,4 on the side don't count
# Out:
# np.float64(2.0)

# %%
# Let's say we wanted the first five rows and five columns
df.iloc[:5, :5]
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age
# 0  29.0000
# 1   0.9167
# 2   2.0000
# 3  30.0000
# 4  25.0000

# %%
# You can also provide a single value, which would then just filter to the row
df.iloc[5]
# Out:
# pclass                         1
# survived                       1
# name         Anderson, Mr. Harry
# sex                         male
# age                         48.0
# sibsp                          0
# parch                          0
# ticket                     19952
# fare                       26.55
# cabin                        E12
# embarked                       S
# boat                           3
# body                         NaN
# home.dest           New York, NY
# Name: 5, dtype: object

# %%
# If we put it into a list, we'll filter to row 5 as a DataFrame
df.iloc[[5]]
# Out:
#    pclass  survived                 name   sex   age  sibsp  parch ticket  \
# 5       1         1  Anderson, Mr. Harry  male  48.0      0      0  19952
#
#     fare cabin embarked boat  body     home.dest
# 5  26.55   E12        S    3   NaN  New York, NY

# %%
# Similarly, if we wanted to filter just a column, we can do df.iloc[:, x] where x is the column we wanted, and then putting it in a list returns it as a DataFrame

# %%
# If we wanted to do this with loc, we'd need to put in the names, for example
df.loc[:, ['pclass', 'survived']]
# Out:
#       pclass  survived
# 0          1         1
# 1          1         1
# 2          1         0
# 3          1         0
# 4          1         0
# ...      ...       ...
# 1304       3         0
# 1305       3         0
# 1306       3         0
# 1307       3         0
# 1308       3         0
#
# [1309 rows x 2 columns]

# %% [markdown]
# #### Filtering Rows

# %%
# Can use boolean expressions to filter
df['age'] > 5
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1304     True
# 1305    False
# 1306     True
# 1307     True
# 1308     True
# Name: age, Length: 1309, dtype: bool

# %%
# Returns whether or not the person that died was over 5 years old.  You can then pass this into df.loc and it'll filter it down to whenever the person was over 5
df.loc[df['age'] > 5]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# ...      ...       ...                                              ...
# 1301       3         0                             Youseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# A useful thing to note is that you can do the inverse of any boolean expression by adding a ~ to the front of it, so let's return everyone except those older than 5
df.loc[
    ~(df['age'] > 5)    # Note that the expression was grouped in () for this to work
]
# Out:
#       pclass  survived                                           name     sex  \
# 1          1         1                 Allison, Master. Hudson Trevor    male
# 2          1         0                   Allison, Miss. Helen Loraine  female
# 15         1         0                            Baumann, Mr. John D    male
# 37         1         1  Bradley, Mr. George ("George Arthur Brayton")    male
# 40         1         0                      Brewe, Dr. Arthur Jackson    male
# ...      ...       ...                                            ...     ...
# 1293       3         0              Williams, Mr. Howard Hugh "Harry"    male
# 1297       3         0                         Wiseman, Mr. Phillippe    male
# 1302       3         0                              Yousif, Mr. Wazli    male
# 1303       3         0                          Yousseff, Mr. Gerious    male
# 1305       3         0                          Zabour, Miss. Thamine  female
#
# ...

# %%
# Use query to do this similarly
df.query('pclass == 3 and age > 5')  # So note the use of () here and also that I'm using boolean to return two conditions
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male  42.0      0
# 601        3         0     Abbott, Master. Eugene Joseph    male  13.0      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male  16.0      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1
# 604        3         1       Abelseth, Miss. Karen Marie  female  16.0      0
# ...      ...       ...                               ...     ...   ...    ...
# 1301       3         0              Youseff, Mr. Gerious    male  45.5      0
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male  27.0      0
# 1308       3         0                Zimmerman, Mr. Leo    male  29.0      0
#
# ...

# %% [markdown]
# #### Summarizing Data

# %%
# For the examples let's use the age column
df['age'].min()
# Out:
# np.float64(0.1667)

# %%
df['age'].max()
# Out:
# np.float64(80.0)

# %%
df['age'].mean()
# Out:
# np.float64(29.8811345124283)

# %%
df['age'].std()  #Standard deviation
# Out:
# np.float64(14.413499699923602)

# %%
df['age'].count()  # The number of values in the column
# Out:
# np.int64(1046)

# %%
df['age'].sum()
# Out:
# np.float64(31255.6667)

# %%
df['age'].quantile()
# Out:
# np.float64(28.0)

# %%
df['age'].quantile([0.25, 0.75])  # Can take a list, and in the example is showing the 25th and 75th quantile for the ages
# Out:
# 0.25    21.0
# 0.75    39.0
# Name: age, dtype: float64

# %%
# Any of these can be run on multiple columns - it returns in a pandas core Series type
type(df[['age', 'name', 'sex']].min())
# Out:
# pandas.core.series.Series

# %%
df[['age', 'name', 'sex']].min()
# Out:
# age                  0.1667
# name    Abbing, Mr. Anthony
# sex                  female
# dtype: object

# %%
# Can use agg to get multiple stats for multiple columns
df[['pclass', 'age', 'fare']].agg(['mean', 'min', 'max'])
# Out:
#         pclass        age        fare
# mean  2.294882  29.881135   33.295479
# min   1.000000   0.166700    0.000000
# max   3.000000  80.000000  512.329200

# %%
# Unique will return all unique values in a column
df['pclass'].unique()
# Out:
# array([1, 2, 3])

# %%
# nunique will give the number of unique values in a column
df['pclass'].nunique()
# Out:
# 3

# %%
# Often used ****** This will give you the instances of that occurrence
df['pclass'].value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
df['pclass'].value_counts(normalize=True)  # This will give a fractional value of occurrence in the dataset
# Out:
# pclass
# 3    0.541635
# 1    0.246753
# 2    0.211612
# Name: proportion, dtype: float64

# %%
# You can do this for multiple columns
df[['pclass', 'sex']].value_counts()
# Out:
# pclass  sex
# 3       male      493
#         female    216
# 1       male      179
# 2       male      171
# 1       female    144
# 2       female    106
# Name: count, dtype: int64

# %%
# If you then run reset_index() on the back, it'll return a DataFrame of the above
df[['pclass', 'sex']].value_counts().reset_index()
# Out:
#    pclass     sex  count
# 0       3    male    493
# 1       3  female    216
# 2       1    male    179
# 3       2    male    171
# 4       1  female    144
# 5       2  female    106

# %% [markdown]
# #### Advanced Column Methods

# %%
# Shift will move the value of the column - can be pos or neg, can set a fill value instead of having NaN by doing ****.shift(1, fill_value=0) for ex, making them zeros

# %%
df[['pclass']].shift(1)
# Out:
#       pclass
# 0        NaN
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# ...      ...
# 1304     3.0
# 1305     3.0
# 1306     3.0
# 1307     3.0
# 1308     3.0
#
# [1309 rows x 1 columns]
