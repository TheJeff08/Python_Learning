# %%
import pandas as pd
import sys

# %%
pd.read_excel("Data Cleaning Start.xlsx", sheet_name="Clean")
# Out:
#     Unnamed: 0           Unnamed: 1                      Unnamed: 2  \
# 0          NaN                 Date                          Client
# 1          NaN  2023-05-30 00:00:00               amazon.com, inc.
# 2          NaN  2023-05-30 00:00:00                    tesla, inc.
# 3          NaN  2023-05-30 00:00:00                  netflix, inc.
# 4          NaN  2023-05-30 00:00:00   the procter & gamble company
# 5          NaN  2023-05-30 00:00:00  the goldman sachs group, inc.
# 6          NaN  2023-05-31 00:00:00           jpmorgan chase & co.
# 7          NaN  2023-05-31 00:00:00                 morgan stanley
# 8          NaN  2023-05-31 00:00:00                 citigroup inc.
# 9          NaN  2023-05-31 00:00:00    bank of america corporation
# 10         NaN  2023-05-31 00:00:00                   walmart inc.
# 11         NaN  2023-05-31 00:00:00             target corporation
# 12         NaN  2023-05-31 00:00:00   costco wholesale corporation
# ...
